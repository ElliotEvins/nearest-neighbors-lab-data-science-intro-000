# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up in NYC.  Liftoff wants it's taxi drivers to target longer rides, as the longer the ride the more money it makes.  LiftOff has the following theory:
#
# * the pickup location of a taxi ride can help predict the length of the ride.
#
#
#
# LiftOff asks us to do some analysis to write a function that will allow it to **predict the length of a taxi ride for any given location **.
#
# Our technique will be the following:
#   * **Collect** Obtain the data containing all of the taxi information, and only select the attributes of taxi trips that we need
#   * ** Explore ** Examine the attributes of our data, and plot some of our data on a map
#   * ** Train ** Write our nearest neighbors formula, and change the number of nearby trips to predict the length of a new trip
#   * ** Predict ** Use our function to predict trip lengths of new locations

# %% [markdown]
# ### Collect and Explore the data

# %% [markdown]
# #### Collect the Data

# %% [markdown]
# Luckily for us, [NYC Open Data](https://opendata.cityofnewyork.us/) collects information about NYC taxi trips and provides this data on [its website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ![](./nyc-taxi.png)

# %% [markdown]
# For your reading pleasure, the data has already been downloaded into the [trips.json](https://github.com/learn-co-curriculum/nearest-neighbors-lab/blob/master/trips.json) file in this lab which you can find here.  We'll use Python's `json` library to take the data from the `trips.json` file and store it as a variable in our notebook.

# %%
import json
# First, read the file
trips_file = open('trips.json')
# Then, convert contents to list of dictionaries 
trips = json.load(trips_file)

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# #### Explore the data

# %% [markdown]
# The next step is to explore the data.  First, let's see how many trips we have.

# %%
len(trips)
# Out:
# 1000

# %% [markdown]
# Not bad at all.  Now let's see what each individual trip looks like.  Each trip is a dictionary, so we can see the attributes of each trip with the `keys` function.

# %%
trips[0].keys()
# Out:
# dict_keys(['dropoff_datetime', 'dropoff_latitude', 'dropoff_longitude', 'fare_amount', 'imp_surcharge', 'mta_tax', 'passenger_count', 'payment_type', 'pickup_datetime', 'pickup_latitude', 'pickup_longitude', 'rate_code', 'tip_amount', 'tolls_amount', 'total_amount', 'trip_distance', 'vendor_id'])

# %% [markdown]
# #### Limit our data

# %% [markdown]
# Ok, now that we have explored some of our data, let's begin to think through what data is relevant for our task.

# %% [markdown]
# Remember that our task is to **use the trip location to predict the length of a trip**.  So let's select the `pickup_latitude`, `pickup_longitude`, and `trip_distance` from each trip.  That will give us the trip location and related `trip_distance` for each trip.  Then based on these **actual** trip distances we can use nearest neighbors to predict an **expected** trip distance for a trip, provided an **actual** location.

# %% [markdown]
# ** Add in about trip distance **

# %% [markdown]
# Write a function called `parse_trips(trips)` that returns a list of the trips with only the following attributes:
# * `trip_distance`
# * `pickup_latitude`
# * `pickup_longitude`

# %%
def parse_trips(trips):
    return list(map(lambda trip: {'trip_distance': trip['trip_distance'], 'pickup_latitude':trip['pickup_latitude'], 'pickup_longitude':trip['pickup_latitude']},trips))

# %%
parsed_trips = parse_trips(trips)
parsed_trips and parsed_trips[0]

# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.78115',
#  'trip_distance': '18.38'}
# Out:
# {'trip_distance': '18.379999999999999',
#  'pickup_latitude': '40.64499',
#  'pickup_longitude': '40.64499'}

# %% [markdown]
# Now, there's just one change to make.  If you look at one of the trips, all of the values are strings.  Let's change them to be floats.

# %%
def float_values(trips):    
    return trips and list(map(lambda trip: {'trip_distance': float(trip['trip_distance']), 'pickup_latitude': float(trip['pickup_latitude']), 'pickup_longitude': float(trip['pickup_longitude'])},trips))

# %%
cleaned_trips = float_values(parsed_trips)

# %%
cleaned_trips

# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': 40.64499},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': 40.766931},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': 40.77773},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': 40.795678},
#  {'trip_distance': 0.84,
#   'pickup_latitude': 40.762912,
#   'pickup_longitude': 40.762912},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.731176,
#   'pickup_longitude': 40.731176},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.800219,
#   'pickup_longitude': 40.800219},
#  {'trip_distance': 17.3,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': 40.648509},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.721897,
#   'pickup_longitude': 40.721897},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.791566,
#   'pickup_longitude': 40.791566},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.744896,
#   'pickup_longitude': 40.744896},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.721951,
#   'pickup_longitude': 40.721951},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.732382,
#   'pickup_longitude': 40.732382},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.768339,
#   'pickup_longitude': 40.768339},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.775933,
#   'pickup_longitude': 40.775933},
#  {'trip_distance': 9.8,
#   'pickup_latitude': 40.794829,
#   'pickup_longitude': 40.794829},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.758647,
#   'pickup_longitude': 40.758647},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.713638,
#   'pickup_longitude': 40.713638},
#  {'trip_distance': 8.4,
#   'pickup_latitude': 40.77403,
#   'pickup_longitude': 40.77403},
#  {'trip_distance': 5.1,
#   'pickup_latitude': 40.728127,
#   'pickup_longitude': 40.728127},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.759671,
#   'pickup_longitude': 40.759671},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.772651,
#   'pickup_longitude': 40.772651},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.770319,
#   'pickup_longitude': 40.770319},
#  {'trip_distance': 1.12,
#   'pickup_latitude': 40.720457,
#   'pickup_longitude': 40.720457},
#  {'trip_distance': 16.0,
#   'pickup_latitude': 40.754789,
#   'pickup_longitude': 40.754789},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.755654,
#   'pickup_longitude': 40.755654},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.741568,
#   'pickup_longitude': 40.741568},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.736907,
#   'pickup_longitude': 40.736907},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.76003,
#   'pickup_longitude': 40.76003},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.721366,
#   'pickup_longitude': 40.721366},
#  {'trip_distance': 1.97,
#   'pickup_latitude': 40.760147,
#   'pickup_longitude': 40.760147},
#  {'trip_distance': 0.96,
#   'pickup_latitude': 40.745847,
#   'pickup_longitude': 40.745847},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.753015,
#   'pickup_longitude': 40.753015},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': 40.644657},
#  {'trip_distance': 1.17,
#   'pickup_latitude': 40.738767,
#   'pickup_longitude': 40.738767},
#  {'trip_distance': 22.8,
#   'pickup_latitude': 40.773797,
#   'pickup_longitude': 40.773797},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.743411,
#   'pickup_longitude': 40.743411},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.758905,
#   'pickup_longitude': 40.758905},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.733877,
#   'pickup_longitude': 40.733877},
#  {'trip_distance': 0.95,
#   'pickup_latitude': 40.726162,
#   'pickup_longitude': 40.726162},
#  {'trip_distance': 5.88,
#   'pickup_latitude': 40.775122,
#   'pickup_longitude': 40.775122},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.75987,
#   'pickup_longitude': 40.75987},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.707087,
#   'pickup_longitude': 40.707087},
#  {'trip_distance': 1.39,
#   'pickup_latitude': 40.741912,
#   'pickup_longitude': 40.741912},
#  {'trip_distance': 11.2,
#   'pickup_latitude': 40.769112,
#   'pickup_longitude': 40.769112},
#  {'trip_distance': 2.56,
#   'pickup_latitude': 40.785807,
#   'pickup_longitude': 40.785807},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.7513,
#   'pickup_longitude': 40.7513},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.733385,
#   'pickup_longitude': 40.733385},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.760257,
#   'pickup_longitude': 40.760257},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.741249,
#   'pickup_longitude': 40.741249},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.759795,
#   'pickup_longitude': 40.759795},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.756636,
#   'pickup_longitude': 40.756636},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.73925,
#   'pickup_longitude': 40.73925},
#  {'trip_distance': 1.07,
#   'pickup_latitude': 40.751055,
#   'pickup_longitude': 40.751055},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.723584,
#   'pickup_longitude': 40.723584},
#  {'trip_distance': 14.43,
#   'pickup_latitude': 40.757037,
#   'pickup_longitude': 40.757037},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.743385,
#   'pickup_longitude': 40.743385},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.737486,
#   'pickup_longitude': 40.737486},
#  {'trip_distance': 1.76,
#   'pickup_latitude': 40.77225,
#   'pickup_longitude': 40.77225},
#  {'trip_distance': 2.45,
#   'pickup_latitude': 40.732882,
#   'pickup_longitude': 40.732882},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.774567,
#   'pickup_longitude': 40.774567},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.757437,
#   'pickup_longitude': 40.757437},
#  {'trip_distance': 2.14,
#   'pickup_latitude': 40.789637,
#   'pickup_longitude': 40.789637},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.754317,
#   'pickup_longitude': 40.754317},
#  {'trip_distance': 0.44,
#   'pickup_latitude': 40.745007,
#   'pickup_longitude': 40.745007},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.734982,
#   'pickup_longitude': 40.734982},
#  {'trip_distance': 1.95, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.738617,
#   'pickup_longitude': 40.738617},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.790712,
#   'pickup_longitude': 40.790712},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.750167,
#   'pickup_longitude': 40.750167},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.732141,
#   'pickup_longitude': 40.732141},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.765758,
#   'pickup_longitude': 40.765758},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.792594,
#   'pickup_longitude': 40.792594},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.762908,
#   'pickup_longitude': 40.762908},
#  {'trip_distance': 4.85,
#   'pickup_latitude': 40.750722,
#   'pickup_longitude': 40.750722},
#  {'trip_distance': 5.09,
#   'pickup_latitude': 40.769887,
#   'pickup_longitude': 40.769887},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.77247,
#   'pickup_longitude': 40.77247},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.764545,
#   'pickup_longitude': 40.764545},
#  {'trip_distance': 16.63,
#   'pickup_latitude': 40.641805,
#   'pickup_longitude': 40.641805},
#  {'trip_distance': 0.79,
#   'pickup_latitude': 40.75224,
#   'pickup_longitude': 40.75224},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.758835,
#   'pickup_longitude': 40.758835},
#  {'trip_distance': 2.04,
#   'pickup_latitude': 40.722785,
#   'pickup_longitude': 40.722785},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.720338,
#   'pickup_longitude': 40.720338},
#  {'trip_distance': 1.65,
#   'pickup_latitude': 40.72973,
#   'pickup_longitude': 40.72973},
#  {'trip_distance': 0.64,
#   'pickup_latitude': 40.760442,
#   'pickup_longitude': 40.760442},
#  {'trip_distance': 1.34,
#   'pickup_latitude': 40.756227,
#   'pickup_longitude': 40.756227},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.751555,
#   'pickup_longitude': 40.751555},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.71333,
#   'pickup_longitude': 40.71333},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.764762,
#   'pickup_longitude': 40.764762},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.763353,
#   'pickup_longitude': 40.763353},
#  {'trip_distance': 0.66,
#   'pickup_latitude': 40.775292,
#   'pickup_longitude': 40.775292},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.779515,
#   'pickup_longitude': 40.779515},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.768322,
#   'pickup_longitude': 40.768322},
#  {'trip_distance': 6.52,
#   'pickup_latitude': 40.766602,
#   'pickup_longitude': 40.766602},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.763684,
#   'pickup_longitude': 40.763684},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.793086,
#   'pickup_longitude': 40.793086},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.773602,
#   'pickup_longitude': 40.773602},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.771909,
#   'pickup_longitude': 40.771909},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.774029,
#   'pickup_longitude': 40.774029},
#  {'trip_distance': 0.48,
#   'pickup_latitude': 40.74964,
#   'pickup_longitude': 40.74964},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.771542,
#   'pickup_longitude': 40.771542},
#  {'trip_distance': 3.89,
#   'pickup_latitude': 40.694095,
#   'pickup_longitude': 40.694095},
#  {'trip_distance': 6.98,
#   'pickup_latitude': 40.756312,
#   'pickup_longitude': 40.756312},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.730282,
#   'pickup_longitude': 40.730282},
#  {'trip_distance': 0.97,
#   'pickup_latitude': 40.777707,
#   'pickup_longitude': 40.777707},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.726087,
#   'pickup_longitude': 40.726087},
#  {'trip_distance': 4.25,
#   'pickup_latitude': 40.738385,
#   'pickup_longitude': 40.738385},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.7678,
#   'pickup_longitude': 40.7678},
#  {'trip_distance': 0.12,
#   'pickup_latitude': 40.742682,
#   'pickup_longitude': 40.742682},
#  {'trip_distance': 1.02,
#   'pickup_latitude': 40.770602,
#   'pickup_longitude': 40.770602},
#  {'trip_distance': 2.39,
#   'pickup_latitude': 40.747967,
#   'pickup_longitude': 40.747967},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.742803,
#   'pickup_longitude': 40.742803},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.755521,
#   'pickup_longitude': 40.755521},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.760528,
#   'pickup_longitude': 40.760528},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.740732,
#   'pickup_longitude': 40.740732},
#  {'trip_distance': 1.11,
#   'pickup_latitude': 40.735497,
#   'pickup_longitude': 40.735497},
#  {'trip_distance': 6.01,
#   'pickup_latitude': 40.715387,
#   'pickup_longitude': 40.715387},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.721587,
#   'pickup_longitude': 40.721587},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': 40.760057},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.740332,
#   'pickup_longitude': 40.740332},
#  {'trip_distance': 5.4,
#   'pickup_latitude': 40.7455,
#   'pickup_longitude': 40.7455},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.733125,
#   'pickup_longitude': 40.733125},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.752092,
#   'pickup_longitude': 40.752092},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.72381,
#   'pickup_longitude': 40.72381},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.767446,
#   'pickup_longitude': 40.767446},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.800479,
#   'pickup_longitude': 40.800479},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.717055,
#   'pickup_longitude': 40.717055},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.748863,
#   'pickup_longitude': 40.748863},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.80474,
#   'pickup_longitude': 40.80474},
#  {'trip_distance': 1.23,
#   'pickup_latitude': 40.762202,
#   'pickup_longitude': 40.762202},
#  {'trip_distance': 5.19, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.740407,
#   'pickup_longitude': 40.740407},
#  {'trip_distance': 5.6,
#   'pickup_latitude': 40.722399,
#   'pickup_longitude': 40.722399},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.747572,
#   'pickup_longitude': 40.747572},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.794651,
#   'pickup_longitude': 40.794651},
#  {'trip_distance': 0.06,
#   'pickup_latitude': 40.751087,
#   'pickup_longitude': 40.751087},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.719886,
#   'pickup_longitude': 40.719886},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.760887,
#   'pickup_longitude': 40.760887},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.727514,
#   'pickup_longitude': 40.727514},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.774453,
#   'pickup_longitude': 40.774453},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.741907,
#   'pickup_longitude': 40.741907},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.735118,
#   'pickup_longitude': 40.735118},
#  {'trip_distance': 8.73,
#   'pickup_latitude': 40.773907,
#   'pickup_longitude': 40.773907},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.758937,
#   'pickup_longitude': 40.758937},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.752144,
#   'pickup_longitude': 40.752144},
#  {'trip_distance': 0.61,
#   'pickup_latitude': 40.745642,
#   'pickup_longitude': 40.745642},
#  {'trip_distance': 1.92,
#   'pickup_latitude': 40.71879,
#   'pickup_longitude': 40.71879},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.739945,
#   'pickup_longitude': 40.739945},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.777575,
#   'pickup_longitude': 40.777575},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.753632,
#   'pickup_longitude': 40.753632},
#  {'trip_distance': 3.61,
#   'pickup_latitude': 40.74733,
#   'pickup_longitude': 40.74733},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.769822,
#   'pickup_longitude': 40.769822},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.724658,
#   'pickup_longitude': 40.724658},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.758345,
#   'pickup_longitude': 40.758345},
#  {'trip_distance': 0.55,
#   'pickup_latitude': 40.764807,
#   'pickup_longitude': 40.764807},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.772847,
#   'pickup_longitude': 40.772847},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.793682,
#   'pickup_longitude': 40.793682},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.760007,
#   'pickup_longitude': 40.760007},
#  {'trip_distance': 1.52,
#   'pickup_latitude': 40.747252,
#   'pickup_longitude': 40.747252},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.756392,
#   'pickup_longitude': 40.756392},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.763685,
#   'pickup_longitude': 40.763685},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.767068,
#   'pickup_longitude': 40.767068},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.77596,
#   'pickup_longitude': 40.77596},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.739617,
#   'pickup_longitude': 40.739617},
#  {'trip_distance': 10.9,
#   'pickup_latitude': 40.751953,
#   'pickup_longitude': 40.751953},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.718635,
#   'pickup_longitude': 40.718635},
#  {'trip_distance': 2.67,
#   'pickup_latitude': 40.7331,
#   'pickup_longitude': 40.7331},
#  {'trip_distance': 0.84,
#   'pickup_latitude': 40.77463,
#   'pickup_longitude': 40.77463},
#  {'trip_distance': 1.89,
#   'pickup_latitude': 40.753675,
#   'pickup_longitude': 40.753675},
#  {'trip_distance': 2.61,
#   'pickup_latitude': 40.763262,
#   'pickup_longitude': 40.763262},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.768895,
#   'pickup_longitude': 40.768895},
#  {'trip_distance': 11.5,
#   'pickup_latitude': 40.641375,
#   'pickup_longitude': 40.641375},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.745472,
#   'pickup_longitude': 40.745472},
#  {'trip_distance': 2.33,
#   'pickup_latitude': 40.707562,
#   'pickup_longitude': 40.707562},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.75331,
#   'pickup_longitude': 40.75331},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.769545,
#   'pickup_longitude': 40.769545},
#  {'trip_distance': 9.37,
#   'pickup_latitude': 40.77411,
#   'pickup_longitude': 40.77411},
#  {'trip_distance': 1.77,
#   'pickup_latitude': 40.720615,
#   'pickup_longitude': 40.720615},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.76305,
#   'pickup_longitude': 40.76305},
#  {'trip_distance': 18.2,
#   'pickup_latitude': 40.648605,
#   'pickup_longitude': 40.648605},
#  {'trip_distance': 2.29,
#   'pickup_latitude': 40.730875,
#   'pickup_longitude': 40.730875},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.763843,
#   'pickup_longitude': 40.763843},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.759867,
#   'pickup_longitude': 40.759867},
#  {'trip_distance': 0.94,
#   'pickup_latitude': 40.77302,
#   'pickup_longitude': 40.77302},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.767437,
#   'pickup_longitude': 40.767437},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.7951,
#   'pickup_longitude': 40.7951},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.78045,
#   'pickup_longitude': 40.78045},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.777608,
#   'pickup_longitude': 40.777608},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.783897,
#   'pickup_longitude': 40.783897},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.738437,
#   'pickup_longitude': 40.738437},
#  {'trip_distance': 2.61,
#   'pickup_latitude': 40.766227,
#   'pickup_longitude': 40.766227},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.7472,
#   'pickup_longitude': 40.7472},
#  {'trip_distance': 1.63,
#   'pickup_latitude': 40.729602,
#   'pickup_longitude': 40.729602},
#  {'trip_distance': 1.86,
#   'pickup_latitude': 40.747295,
#   'pickup_longitude': 40.747295},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.764276,
#   'pickup_longitude': 40.764276},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.717463,
#   'pickup_longitude': 40.717463},
#  {'trip_distance': 3.06,
#   'pickup_latitude': 40.756667,
#   'pickup_longitude': 40.756667},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.723036,
#   'pickup_longitude': 40.723036},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.742832,
#   'pickup_longitude': 40.742832},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.759825,
#   'pickup_longitude': 40.759825},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.770567,
#   'pickup_longitude': 40.770567},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.743565,
#   'pickup_longitude': 40.743565},
#  {'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': 40.761372},
#  {'trip_distance': 0.06,
#   'pickup_latitude': 40.725012,
#   'pickup_longitude': 40.725012},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.751251,
#   'pickup_longitude': 40.751251},
#  {'trip_distance': 0.64,
#   'pickup_latitude': 40.742522,
#   'pickup_longitude': 40.742522},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': 40.762107},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.787171,
#   'pickup_longitude': 40.787171},
#  {'trip_distance': 0.87,
#   'pickup_latitude': 40.739887,
#   'pickup_longitude': 40.739887},
#  {'trip_distance': 2.47,
#   'pickup_latitude': 40.775297,
#   'pickup_longitude': 40.775297},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.743232,
#   'pickup_longitude': 40.743232},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.757386,
#   'pickup_longitude': 40.757386},
#  {'trip_distance': 0.57,
#   'pickup_latitude': 40.749027,
#   'pickup_longitude': 40.749027},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.752385,
#   'pickup_longitude': 40.752385},
#  {'trip_distance': 4.0,
#   'pickup_latitude': 40.721988,
#   'pickup_longitude': 40.721988},
#  {'trip_distance': 1.04,
#   'pickup_latitude': 40.742422,
#   'pickup_longitude': 40.742422},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.735396,
#   'pickup_longitude': 40.735396},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.749873,
#   'pickup_longitude': 40.749873},
#  {'trip_distance': 1.35,
#   'pickup_latitude': 40.779447,
#   'pickup_longitude': 40.779447},
#  {'trip_distance': 5.0,
#   'pickup_latitude': 40.730843,
#   'pickup_longitude': 40.730843},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.750116,
#   'pickup_longitude': 40.750116},
#  {'trip_distance': 5.2,
#   'pickup_latitude': 40.701734,
#   'pickup_longitude': 40.701734},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.72635,
#   'pickup_longitude': 40.72635},
#  {'trip_distance': 5.5,
#   'pickup_latitude': 40.688702,
#   'pickup_longitude': 40.688702},
#  {'trip_distance': 1.49,
#   'pickup_latitude': 40.771385,
#   'pickup_longitude': 40.771385},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.715884,
#   'pickup_longitude': 40.715884},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.790046,
#   'pickup_longitude': 40.790046},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.76418,
#   'pickup_longitude': 40.76418},
#  {'trip_distance': 5.3,
#   'pickup_latitude': 40.76041,
#   'pickup_longitude': 40.76041},
#  {'trip_distance': 0.43,
#   'pickup_latitude': 40.745647,
#   'pickup_longitude': 40.745647},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.793261,
#   'pickup_longitude': 40.793261},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.762111,
#   'pickup_longitude': 40.762111},
#  {'trip_distance': 1.65,
#   'pickup_latitude': 40.74733,
#   'pickup_longitude': 40.74733},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.74886,
#   'pickup_longitude': 40.74886},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.730145,
#   'pickup_longitude': 40.730145},
#  {'trip_distance': 6.6,
#   'pickup_latitude': 40.75318,
#   'pickup_longitude': 40.75318},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.829557,
#   'pickup_longitude': 40.829557},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.743102,
#   'pickup_longitude': 40.743102},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.750445,
#   'pickup_longitude': 40.750445},
#  {'trip_distance': 8.26,
#   'pickup_latitude': 40.743475,
#   'pickup_longitude': 40.743475},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.762752,
#   'pickup_longitude': 40.762752},
#  {'trip_distance': 3.02,
#   'pickup_latitude': 40.765577,
#   'pickup_longitude': 40.765577},
#  {'trip_distance': 0.98,
#   'pickup_latitude': 40.750027,
#   'pickup_longitude': 40.750027},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.751947,
#   'pickup_longitude': 40.751947},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.71972,
#   'pickup_longitude': 40.71972},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.78079,
#   'pickup_longitude': 40.78079},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.751607,
#   'pickup_longitude': 40.751607},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.745595,
#   'pickup_longitude': 40.745595},
#  {'trip_distance': 7.46,
#   'pickup_latitude': 40.72245,
#   'pickup_longitude': 40.72245},
#  {'trip_distance': 3.03,
#   'pickup_latitude': 40.702557,
#   'pickup_longitude': 40.702557},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.734659,
#   'pickup_longitude': 40.734659},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.764774,
#   'pickup_longitude': 40.764774},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.723516,
#   'pickup_longitude': 40.723516},
#  {'trip_distance': 1.88,
#   'pickup_latitude': 40.781072,
#   'pickup_longitude': 40.781072},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.793005,
#   'pickup_longitude': 40.793005},
#  {'trip_distance': 5.29,
#   'pickup_latitude': 40.721025,
#   'pickup_longitude': 40.721025},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.768497,
#   'pickup_longitude': 40.768497},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.80726,
#   'pickup_longitude': 40.80726},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.773715,
#   'pickup_longitude': 40.773715},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.780082,
#   'pickup_longitude': 40.780082},
#  {'trip_distance': 7.4,
#   'pickup_latitude': 40.741824,
#   'pickup_longitude': 40.741824},
#  {'trip_distance': 3.12,
#   'pickup_latitude': 40.742112,
#   'pickup_longitude': 40.742112},
#  {'trip_distance': 5.4,
#   'pickup_latitude': 40.725925,
#   'pickup_longitude': 40.725925},
#  {'trip_distance': 20.5,
#   'pickup_latitude': 40.645718,
#   'pickup_longitude': 40.645718},
#  {'trip_distance': 9.4,
#   'pickup_latitude': 40.718398,
#   'pickup_longitude': 40.718398},
#  {'trip_distance': 2.8, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.736343,
#   'pickup_longitude': 40.736343},
#  {'trip_distance': 17.65,
#   'pickup_latitude': 40.753827,
#   'pickup_longitude': 40.753827},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.750693,
#   'pickup_longitude': 40.750693},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.745964,
#   'pickup_longitude': 40.745964},
#  {'trip_distance': 1.93,
#   'pickup_latitude': 40.740482,
#   'pickup_longitude': 40.740482},
#  {'trip_distance': 0.3, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 8.74,
#   'pickup_latitude': 40.803842,
#   'pickup_longitude': 40.803842},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.797632,
#   'pickup_longitude': 40.797632},
#  {'trip_distance': 19.05,
#   'pickup_latitude': 40.645322,
#   'pickup_longitude': 40.645322},
#  {'trip_distance': 0.75,
#   'pickup_latitude': 40.749207,
#   'pickup_longitude': 40.749207},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.765548,
#   'pickup_longitude': 40.765548},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.760289,
#   'pickup_longitude': 40.760289},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.778967,
#   'pickup_longitude': 40.778967},
#  {'trip_distance': 3.59,
#   'pickup_latitude': 40.7582,
#   'pickup_longitude': 40.7582},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.730709,
#   'pickup_longitude': 40.730709},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.7456,
#   'pickup_longitude': 40.7456},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.719471,
#   'pickup_longitude': 40.719471},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.75619,
#   'pickup_longitude': 40.75619},
#  {'trip_distance': 3.08,
#   'pickup_latitude': 40.639542,
#   'pickup_longitude': 40.639542},
#  {'trip_distance': 1.77,
#   'pickup_latitude': 40.78366,
#   'pickup_longitude': 40.78366},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.7464,
#   'pickup_longitude': 40.7464},
#  {'trip_distance': 3.98,
#   'pickup_latitude': 40.727475,
#   'pickup_longitude': 40.727475},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.735015,
#   'pickup_longitude': 40.735015},
#  {'trip_distance': 1.1, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 1.33, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.754176,
#   'pickup_longitude': 40.754176},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.740112,
#   'pickup_longitude': 40.740112},
#  {'trip_distance': 2.07,
#   'pickup_latitude': 40.719972,
#   'pickup_longitude': 40.719972},
#  {'trip_distance': 2.43,
#   'pickup_latitude': 40.70517,
#   'pickup_longitude': 40.70517},
#  {'trip_distance': 2.18,
#   'pickup_latitude': 40.789142,
#   'pickup_longitude': 40.789142},
#  {'trip_distance': 4.72,
#   'pickup_latitude': 40.749115,
#   'pickup_longitude': 40.749115},
#  {'trip_distance': 2.15,
#   'pickup_latitude': 40.76443,
#   'pickup_longitude': 40.76443},
#  {'trip_distance': 3.5,
#   'pickup_latitude': 40.756477,
#   'pickup_longitude': 40.756477},
#  {'trip_distance': 1.52,
#   'pickup_latitude': 40.746142,
#   'pickup_longitude': 40.746142},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.747856,
#   'pickup_longitude': 40.747856},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.772615,
#   'pickup_longitude': 40.772615},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.761912,
#   'pickup_longitude': 40.761912},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.740991,
#   'pickup_longitude': 40.740991},
#  {'trip_distance': 3.84,
#   'pickup_latitude': 40.764115,
#   'pickup_longitude': 40.764115},
#  {'trip_distance': 16.4,
#   'pickup_latitude': 40.728808,
#   'pickup_longitude': 40.728808},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.725511,
#   'pickup_longitude': 40.725511},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.768967,
#   'pickup_longitude': 40.768967},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.75652,
#   'pickup_longitude': 40.75652},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.751217,
#   'pickup_longitude': 40.751217},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.779557,
#   'pickup_longitude': 40.779557},
#  {'trip_distance': 12.06,
#   'pickup_latitude': 40.771472,
#   'pickup_longitude': 40.771472},
#  {'trip_distance': 0.45,
#   'pickup_latitude': 40.73832,
#   'pickup_longitude': 40.73832},
#  {'trip_distance': 19.03,
#   'pickup_latitude': 40.643172,
#   'pickup_longitude': 40.643172},
#  {'trip_distance': 0.45,
#   'pickup_latitude': 40.769387,
#   'pickup_longitude': 40.769387},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.731752,
#   'pickup_longitude': 40.731752},
#  {'trip_distance': 16.1,
#   'pickup_latitude': 40.745874,
#   'pickup_longitude': 40.745874},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.767867,
#   'pickup_longitude': 40.767867},
#  {'trip_distance': 1.04,
#   'pickup_latitude': 40.766245,
#   'pickup_longitude': 40.766245},
#  {'trip_distance': 0.76,
#   'pickup_latitude': 40.753485,
#   'pickup_longitude': 40.753485},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.726597,
#   'pickup_longitude': 40.726597},
#  {'trip_distance': 0.59,
#   'pickup_latitude': 40.7446,
#   'pickup_longitude': 40.7446},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.756806,
#   'pickup_longitude': 40.756806},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.783447,
#   'pickup_longitude': 40.783447},
#  {'trip_distance': 6.13,
#   'pickup_latitude': 40.758985,
#   'pickup_longitude': 40.758985},
#  {'trip_distance': 17.5,
#   'pickup_latitude': 40.645316,
#   'pickup_longitude': 40.645316},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': 40.762868},
#  {'trip_distance': 0.65,
#   'pickup_latitude': 40.761322,
#   'pickup_longitude': 40.761322},
#  {'trip_distance': 9.61,
#   'pickup_latitude': 40.771097,
#   'pickup_longitude': 40.771097},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.760195,
#   'pickup_longitude': 40.760195},
#  {'trip_distance': 4.92,
#   'pickup_latitude': 40.73286,
#   'pickup_longitude': 40.73286},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.75952,
#   'pickup_longitude': 40.75952},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.821517,
#   'pickup_longitude': 40.821517},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.734922,
#   'pickup_longitude': 40.734922},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.757594,
#   'pickup_longitude': 40.757594},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.748042,
#   'pickup_longitude': 40.748042},
#  {'trip_distance': 6.04,
#   'pickup_latitude': 40.74957,
#   'pickup_longitude': 40.74957},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.759663,
#   'pickup_longitude': 40.759663},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.756397,
#   'pickup_longitude': 40.756397},
#  {'trip_distance': 1.56,
#   'pickup_latitude': 40.68078,
#   'pickup_longitude': 40.68078},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.749994,
#   'pickup_longitude': 40.749994},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.801351,
#   'pickup_longitude': 40.801351},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.766223,
#   'pickup_longitude': 40.766223},
#  {'trip_distance': 2.08,
#   'pickup_latitude': 40.740045,
#   'pickup_longitude': 40.740045},
#  {'trip_distance': 6.58,
#   'pickup_latitude': 40.801657,
#   'pickup_longitude': 40.801657},
#  {'trip_distance': 5.25,
#   'pickup_latitude': 40.738722,
#   'pickup_longitude': 40.738722},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.742172,
#   'pickup_longitude': 40.742172},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.775633,
#   'pickup_longitude': 40.775633},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.792377,
#   'pickup_longitude': 40.792377},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.659956,
#   'pickup_longitude': 40.659956},
#  {'trip_distance': 0.78,
#   'pickup_latitude': 40.7655,
#   'pickup_longitude': 40.7655},
#  {'trip_distance': 7.4,
#   'pickup_latitude': 40.737997,
#   'pickup_longitude': 40.737997},
#  {'trip_distance': 8.8,
#   'pickup_latitude': 40.711467,
#   'pickup_longitude': 40.711467},
#  {'trip_distance': 0.1, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 3.63,
#   'pickup_latitude': 40.710822,
#   'pickup_longitude': 40.710822},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.763597,
#   'pickup_longitude': 40.763597},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.744277,
#   'pickup_longitude': 40.744277},
#  {'trip_distance': 6.54,
#   'pickup_latitude': 40.774152,
#   'pickup_longitude': 40.774152},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.773736,
#   'pickup_longitude': 40.773736},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.740018,
#   'pickup_longitude': 40.740018},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.750094,
#   'pickup_longitude': 40.750094},
#  {'trip_distance': 2.06,
#   'pickup_latitude': 40.741317,
#   'pickup_longitude': 40.741317},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.75885,
#   'pickup_longitude': 40.75885},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.687077,
#   'pickup_longitude': 40.687077},
#  {'trip_distance': 0.72,
#   'pickup_latitude': 40.76705,
#   'pickup_longitude': 40.76705},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.72257,
#   'pickup_longitude': 40.72257},
#  {'trip_distance': 0.25,
#   'pickup_latitude': 40.77958,
#   'pickup_longitude': 40.77958},
#  {'trip_distance': 1.34,
#   'pickup_latitude': 40.7385,
#   'pickup_longitude': 40.7385},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.770377,
#   'pickup_longitude': 40.770377},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.75906,
#   'pickup_longitude': 40.75906},
#  {'trip_distance': 2.24,
#   'pickup_latitude': 40.689827,
#   'pickup_longitude': 40.689827},
#  {'trip_distance': 17.55,
#   'pickup_latitude': 40.766367,
#   'pickup_longitude': 40.766367},
#  {'trip_distance': 3.08,
#   'pickup_latitude': 40.717302,
#   'pickup_longitude': 40.717302},
#  {'trip_distance': 24.55,
#   'pickup_latitude': 40.642817,
#   'pickup_longitude': 40.642817},
#  {'trip_distance': 5.1,
#   'pickup_latitude': 40.766804,
#   'pickup_longitude': 40.766804},
#  {'trip_distance': 1.18,
#   'pickup_latitude': 40.762317,
#   'pickup_longitude': 40.762317},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.734099,
#   'pickup_longitude': 40.734099},
#  {'trip_distance': 2.58,
#   'pickup_latitude': 40.770737,
#   'pickup_longitude': 40.770737},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.724919,
#   'pickup_longitude': 40.724919},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.729687,
#   'pickup_longitude': 40.729687},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.744083,
#   'pickup_longitude': 40.744083},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.726413,
#   'pickup_longitude': 40.726413},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.794009,
#   'pickup_longitude': 40.794009},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.74589,
#   'pickup_longitude': 40.74589},
#  {'trip_distance': 0.35,
#   'pickup_latitude': 40.75284,
#   'pickup_longitude': 40.75284},
#  {'trip_distance': 1.14,
#   'pickup_latitude': 40.777652,
#   'pickup_longitude': 40.777652},
#  {'trip_distance': 2.06,
#   'pickup_latitude': 40.726935,
#   'pickup_longitude': 40.726935},
#  {'trip_distance': 1.01,
#   'pickup_latitude': 40.74969,
#   'pickup_longitude': 40.74969},
#  {'trip_distance': 5.14,
#   'pickup_latitude': 40.709355,
#   'pickup_longitude': 40.709355},
#  {'trip_distance': 3.0,
#   'pickup_latitude': 40.750099,
#   'pickup_longitude': 40.750099},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.777513,
#   'pickup_longitude': 40.777513},
#  {'trip_distance': 21.44,
#   'pickup_latitude': 40.64534,
#   'pickup_longitude': 40.64534},
#  {'trip_distance': 0.76,
#   'pickup_latitude': 40.794572,
#   'pickup_longitude': 40.794572},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.76084,
#   'pickup_longitude': 40.76084},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.758902,
#   'pickup_longitude': 40.758902},
#  {'trip_distance': 1.12,
#   'pickup_latitude': 40.756082,
#   'pickup_longitude': 40.756082},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.746631,
#   'pickup_longitude': 40.746631},
#  {'trip_distance': 1.06,
#   'pickup_latitude': 40.787612,
#   'pickup_longitude': 40.787612},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.748875,
#   'pickup_longitude': 40.748875},
#  {'trip_distance': 1.18, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.734924,
#   'pickup_longitude': 40.734924},
#  {'trip_distance': 1.24,
#   'pickup_latitude': 40.755682,
#   'pickup_longitude': 40.755682},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.757465,
#   'pickup_longitude': 40.757465},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.751163,
#   'pickup_longitude': 40.751163},
#  {'trip_distance': 5.64,
#   'pickup_latitude': 40.754707,
#   'pickup_longitude': 40.754707},
#  {'trip_distance': 1.14,
#   'pickup_latitude': 40.768512,
#   'pickup_longitude': 40.768512},
#  {'trip_distance': 0.37,
#   'pickup_latitude': 40.770792,
#   'pickup_longitude': 40.770792},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.780672,
#   'pickup_longitude': 40.780672},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.733568,
#   'pickup_longitude': 40.733568},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.74998,
#   'pickup_longitude': 40.74998},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.72235,
#   'pickup_longitude': 40.72235},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.77081,
#   'pickup_longitude': 40.77081},
#  {'trip_distance': 4.33,
#   'pickup_latitude': 40.771152,
#   'pickup_longitude': 40.771152},
#  {'trip_distance': 19.6,
#   'pickup_latitude': 40.790777,
#   'pickup_longitude': 40.790777},
#  {'trip_distance': 4.0,
#   'pickup_latitude': 40.716232,
#   'pickup_longitude': 40.716232},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.74277,
#   'pickup_longitude': 40.74277},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.726791,
#   'pickup_longitude': 40.726791},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.774935,
#   'pickup_longitude': 40.774935},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.752832,
#   'pickup_longitude': 40.752832},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.732783,
#   'pickup_longitude': 40.732783},
#  {'trip_distance': 1.76,
#   'pickup_latitude': 40.75176,
#   'pickup_longitude': 40.75176},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.772827,
#   'pickup_longitude': 40.772827},
#  {'trip_distance': 6.2,
#   'pickup_latitude': 40.786305,
#   'pickup_longitude': 40.786305},
#  {'trip_distance': 5.53,
#   'pickup_latitude': 40.71986,
#   'pickup_longitude': 40.71986},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.748193,
#   'pickup_longitude': 40.748193},
#  {'trip_distance': 4.7,
#   'pickup_latitude': 40.734642,
#   'pickup_longitude': 40.734642},
#  {'trip_distance': 2.79,
#   'pickup_latitude': 40.758495,
#   'pickup_longitude': 40.758495},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.750711,
#   'pickup_longitude': 40.750711},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.751085,
#   'pickup_longitude': 40.751085},
#  {'trip_distance': 8.44,
#   'pickup_latitude': 40.696647,
#   'pickup_longitude': 40.696647},
#  {'trip_distance': 1.25,
#   'pickup_latitude': 40.766092,
#   'pickup_longitude': 40.766092},
#  {'trip_distance': 9.41,
#   'pickup_latitude': 40.77293,
#   'pickup_longitude': 40.77293},
#  {'trip_distance': 23.7,
#   'pickup_latitude': 40.644032,
#   'pickup_longitude': 40.644032},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.758261,
#   'pickup_longitude': 40.758261},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.778392,
#   'pickup_longitude': 40.778392},
#  {'trip_distance': 0.72,
#   'pickup_latitude': 40.758372,
#   'pickup_longitude': 40.758372},
#  {'trip_distance': 6.2,
#   'pickup_latitude': 40.752788,
#   'pickup_longitude': 40.752788},
#  {'trip_distance': 3.05,
#   'pickup_latitude': 40.741972,
#   'pickup_longitude': 40.741972},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.764972,
#   'pickup_longitude': 40.764972},
#  {'trip_distance': 0.72,
#   'pickup_latitude': 40.742227,
#   'pickup_longitude': 40.742227},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.743594,
#   'pickup_longitude': 40.743594},
#  {'trip_distance': 4.83,
#   'pickup_latitude': 40.774852,
#   'pickup_longitude': 40.774852},
#  {'trip_distance': 13.75,
#   'pickup_latitude': 40.786657,
#   'pickup_longitude': 40.786657},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.731236,
#   'pickup_longitude': 40.731236},
#  {'trip_distance': 4.8,
#   'pickup_latitude': 40.724197,
#   'pickup_longitude': 40.724197},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.735687,
#   'pickup_longitude': 40.735687},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.724007,
#   'pickup_longitude': 40.724007},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.751962,
#   'pickup_longitude': 40.751962},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.744422,
#   'pickup_longitude': 40.744422},
#  {'trip_distance': 2.11,
#   'pickup_latitude': 40.76944,
#   'pickup_longitude': 40.76944},
#  {'trip_distance': 2.54,
#   'pickup_latitude': 40.755972,
#   'pickup_longitude': 40.755972},
#  {'trip_distance': 8.47,
#   'pickup_latitude': 40.782482,
#   'pickup_longitude': 40.782482},
#  {'trip_distance': 1.98,
#   'pickup_latitude': 40.739142,
#   'pickup_longitude': 40.739142},
#  {'trip_distance': 1.31,
#   'pickup_latitude': 40.752412,
#   'pickup_longitude': 40.752412},
#  {'trip_distance': 3.2, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.771168,
#   'pickup_longitude': 40.771168},
#  {'trip_distance': 6.7,
#   'pickup_latitude': 40.756005,
#   'pickup_longitude': 40.756005},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.778415,
#   'pickup_longitude': 40.778415},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.766653,
#   'pickup_longitude': 40.766653},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.746032,
#   'pickup_longitude': 40.746032},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.763352,
#   'pickup_longitude': 40.763352},
#  {'trip_distance': 6.89,
#   'pickup_latitude': 40.755782,
#   'pickup_longitude': 40.755782},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.769837,
#   'pickup_longitude': 40.769837},
#  {'trip_distance': 8.2,
#   'pickup_latitude': 40.773009,
#   'pickup_longitude': 40.773009},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.799458,
#   'pickup_longitude': 40.799458},
#  {'trip_distance': 1.18,
#   'pickup_latitude': 40.777555,
#   'pickup_longitude': 40.777555},
#  {'trip_distance': 0.68,
#   'pickup_latitude': 40.80409,
#   'pickup_longitude': 40.80409},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.713948,
#   'pickup_longitude': 40.713948},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.741453,
#   'pickup_longitude': 40.741453},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.79858,
#   'pickup_longitude': 40.79858},
#  {'trip_distance': 7.1,
#   'pickup_latitude': 40.721519,
#   'pickup_longitude': 40.721519},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.744341,
#   'pickup_longitude': 40.744341},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.750106,
#   'pickup_longitude': 40.750106},
#  {'trip_distance': 4.59,
#   'pickup_latitude': 40.815817,
#   'pickup_longitude': 40.815817},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.772255,
#   'pickup_longitude': 40.772255},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.756412,
#   'pickup_longitude': 40.756412},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.729556,
#   'pickup_longitude': 40.729556},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.774627,
#   'pickup_longitude': 40.774627},
#  {'trip_distance': 6.8,
#   'pickup_latitude': 40.744418,
#   'pickup_longitude': 40.744418},
#  {'trip_distance': 6.4,
#   'pickup_latitude': 40.795953,
#   'pickup_longitude': 40.795953},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.735785,
#   'pickup_longitude': 40.735785},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.741275,
#   'pickup_longitude': 40.741275},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.759037,
#   'pickup_longitude': 40.759037},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.7642,
#   'pickup_longitude': 40.7642},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.779383,
#   'pickup_longitude': 40.779383},
#  {'trip_distance': 3.42,
#   'pickup_latitude': 40.72638,
#   'pickup_longitude': 40.72638},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.716736,
#   'pickup_longitude': 40.716736},
#  {'trip_distance': 10.74,
#   'pickup_latitude': 40.751872,
#   'pickup_longitude': 40.751872},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.774462,
#   'pickup_longitude': 40.774462},
#  {'trip_distance': 4.3,
#   'pickup_latitude': 40.748208,
#   'pickup_longitude': 40.748208},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.756054,
#   'pickup_longitude': 40.756054},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.759193,
#   'pickup_longitude': 40.759193},
#  {'trip_distance': 0.95,
#   'pickup_latitude': 40.7439,
#   'pickup_longitude': 40.7439},
#  {'trip_distance': 7.04,
#   'pickup_latitude': 40.712612,
#   'pickup_longitude': 40.712612},
#  {'trip_distance': 1.71,
#   'pickup_latitude': 40.751285,
#   'pickup_longitude': 40.751285},
#  {'trip_distance': 0.79,
#   'pickup_latitude': 40.75262,
#   'pickup_longitude': 40.75262},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.728885,
#   'pickup_longitude': 40.728885},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.753302,
#   'pickup_longitude': 40.753302},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.759795,
#   'pickup_longitude': 40.759795},
#  {'trip_distance': 5.1,
#   'pickup_latitude': 40.727368,
#   'pickup_longitude': 40.727368},
#  {'trip_distance': 0.62,
#   'pickup_latitude': 40.7595,
#   'pickup_longitude': 40.7595},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.751837,
#   'pickup_longitude': 40.751837},
#  {'trip_distance': 1.71,
#   'pickup_latitude': 40.742032,
#   'pickup_longitude': 40.742032},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.755123,
#   'pickup_longitude': 40.755123},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.726783,
#   'pickup_longitude': 40.726783},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.768924,
#   'pickup_longitude': 40.768924},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.748232,
#   'pickup_longitude': 40.748232},
#  {'trip_distance': 3.93,
#   'pickup_latitude': 40.70205,
#   'pickup_longitude': 40.70205},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.763197,
#   'pickup_longitude': 40.763197},
#  {'trip_distance': 4.3,
#   'pickup_latitude': 40.720794,
#   'pickup_longitude': 40.720794},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': 40.760644},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.743367,
#   'pickup_longitude': 40.743367},
#  {'trip_distance': 8.7,
#   'pickup_latitude': 40.749792,
#   'pickup_longitude': 40.749792},
#  {'trip_distance': 2.63,
#   'pickup_latitude': 40.754807,
#   'pickup_longitude': 40.754807},
#  {'trip_distance': 7.78,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': 40.64483},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.767759,
#   'pickup_longitude': 40.767759},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.762243,
#   'pickup_longitude': 40.762243},
#  {'trip_distance': 4.62,
#   'pickup_latitude': 40.730735,
#   'pickup_longitude': 40.730735},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.738672,
#   'pickup_longitude': 40.738672},
#  {'trip_distance': 1.53,
#   'pickup_latitude': 40.774752,
#   'pickup_longitude': 40.774752},
#  {'trip_distance': 7.1,
#   'pickup_latitude': 40.777867,
#   'pickup_longitude': 40.777867},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.742502,
#   'pickup_longitude': 40.742502},
#  {'trip_distance': 2.96,
#   'pickup_latitude': 40.76532,
#   'pickup_longitude': 40.76532},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.722856,
#   'pickup_longitude': 40.722856},
#  {'trip_distance': 2.28,
#   'pickup_latitude': 40.777252,
#   'pickup_longitude': 40.777252},
#  {'trip_distance': 3.59,
#   'pickup_latitude': 40.740912,
#   'pickup_longitude': 40.740912},
#  {'trip_distance': 5.17,
#   'pickup_latitude': 40.798562,
#   'pickup_longitude': 40.798562},
#  {'trip_distance': 3.7,
#   'pickup_latitude': 40.71422,
#   'pickup_longitude': 40.71422},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.748567,
#   'pickup_longitude': 40.748567},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.757222,
#   'pickup_longitude': 40.757222},
#  {'trip_distance': 2.76,
#   'pickup_latitude': 40.751325,
#   'pickup_longitude': 40.751325},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.729357,
#   'pickup_longitude': 40.729357},
#  {'trip_distance': 8.9,
#   'pickup_latitude': 40.767302,
#   'pickup_longitude': 40.767302},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.793391,
#   'pickup_longitude': 40.793391},
# ...
#  {'trip_distance': 2.82,
#   'pickup_latitude': 40.770377,
#   'pickup_longitude': 40.770377},
#  {'trip_distance': 2.11,
#   'pickup_latitude': 40.763152,
#   'pickup_longitude': 40.763152},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.75781,
#   'pickup_longitude': 40.75781},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.745593,
#   'pickup_longitude': 40.745593},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.783545,
#   'pickup_longitude': 40.783545},
#  {'trip_distance': 0.77,
#   'pickup_latitude': 40.757605,
#   'pickup_longitude': 40.757605},
#  {'trip_distance': 1.02,
#   'pickup_latitude': 40.75899,
#   'pickup_longitude': 40.75899},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.713662,
#   'pickup_longitude': 40.713662},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.776252,
#   'pickup_longitude': 40.776252},
#  {'trip_distance': 2.56,
#   'pickup_latitude': 40.764,
#   'pickup_longitude': 40.764},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.74787,
#   'pickup_longitude': 40.74787},
#  {'trip_distance': 2.18,
#   'pickup_latitude': 40.748717,
#   'pickup_longitude': 40.748717},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.771905,
#   'pickup_longitude': 40.771905},
#  {'trip_distance': 3.01,
#   'pickup_latitude': 40.783138,
#   'pickup_longitude': 40.783138},
#  {'trip_distance': 0.72,
#   'pickup_latitude': 40.75708,
#   'pickup_longitude': 40.75708},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.848462,
#   'pickup_longitude': 40.848462},
#  {'trip_distance': 0.49,
#   'pickup_latitude': 40.744697,
#   'pickup_longitude': 40.744697},
#  {'trip_distance': 6.52,
#   'pickup_latitude': 40.768147,
#   'pickup_longitude': 40.768147},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.741328,
#   'pickup_longitude': 40.741328},
#  {'trip_distance': 2.07,
#   'pickup_latitude': 40.77847,
#   'pickup_longitude': 40.77847},
#  {'trip_distance': 4.8,
#   'pickup_latitude': 40.782873,
#   'pickup_longitude': 40.782873},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.78711,
#   'pickup_longitude': 40.78711},
#  {'trip_distance': 1.93,
#   'pickup_latitude': 40.762862,
#   'pickup_longitude': 40.762862},
#  {'trip_distance': 5.79,
#   'pickup_latitude': 40.78579,
#   'pickup_longitude': 40.78579},
#  {'trip_distance': 2.62,
#   'pickup_latitude': 40.782512,
#   'pickup_longitude': 40.782512},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.771552,
#   'pickup_longitude': 40.771552},
#  {'trip_distance': 5.37,
#   'pickup_latitude': 40.759172,
#   'pickup_longitude': 40.759172},
#  {'trip_distance': 2.46,
#   'pickup_latitude': 40.740622,
#   'pickup_longitude': 40.740622},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.750938,
#   'pickup_longitude': 40.750938},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.77435,
#   'pickup_longitude': 40.77435},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 40.77831,
#   'pickup_longitude': 40.77831},
#  {'trip_distance': 2.48,
#   'pickup_latitude': 40.760477,
#   'pickup_longitude': 40.760477},
#  {'trip_distance': 0.53,
#   'pickup_latitude': 40.77338,
#   'pickup_longitude': 40.77338},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.760643,
#   'pickup_longitude': 40.760643},
#  {'trip_distance': 6.07,
#   'pickup_latitude': 40.68703,
#   'pickup_longitude': 40.68703},
#  {'trip_distance': 2.27,
#   'pickup_latitude': 40.77164,
#   'pickup_longitude': 40.77164},
#  {'trip_distance': 1.67,
#   'pickup_latitude': 40.764902,
#   'pickup_longitude': 40.764902},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.767331,
#   'pickup_longitude': 40.767331},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.77919,
#   'pickup_longitude': 40.77919},
#  {'trip_distance': 4.52,
#   'pickup_latitude': 40.763407,
#   'pickup_longitude': 40.763407},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.751124,
#   'pickup_longitude': 40.751124},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.73599,
#   'pickup_longitude': 40.73599},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.761058,
#   'pickup_longitude': 40.761058},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.745909,
#   'pickup_longitude': 40.745909},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.744849,
#   'pickup_longitude': 40.744849},
#  {'trip_distance': 4.28,
#   'pickup_latitude': 40.750342,
#   'pickup_longitude': 40.750342},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.763665,
#   'pickup_longitude': 40.763665},
#  {'trip_distance': 2.65,
#   'pickup_latitude': 40.765862,
#   'pickup_longitude': 40.765862},
#  {'trip_distance': 1.56,
#   'pickup_latitude': 40.75729,
#   'pickup_longitude': 40.75729},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.763148,
#   'pickup_longitude': 40.763148},
#  {'trip_distance': 1.62,
#   'pickup_latitude': 40.70626,
#   'pickup_longitude': 40.70626},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.782011,
#   'pickup_longitude': 40.782011},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.671487,
#   'pickup_longitude': 40.671487},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.753034,
#   'pickup_longitude': 40.753034},
#  {'trip_distance': 0.81,
#   'pickup_latitude': 40.744997,
#   'pickup_longitude': 40.744997},
#  {'trip_distance': 4.11,
#   'pickup_latitude': 40.721882,
#   'pickup_longitude': 40.721882},
#  {'trip_distance': 7.6,
#   'pickup_latitude': 40.752342,
#   'pickup_longitude': 40.752342},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.709415,
#   'pickup_longitude': 40.709415},
#  {'trip_distance': 0.58,
#   'pickup_latitude': 40.755637,
#   'pickup_longitude': 40.755637},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.780847,
#   'pickup_longitude': 40.780847},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.73668,
#   'pickup_longitude': 40.73668},
#  {'trip_distance': 7.8,
#   'pickup_latitude': 40.707517,
#   'pickup_longitude': 40.707517},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.73706,
#   'pickup_longitude': 40.73706},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.769119,
#   'pickup_longitude': 40.769119},
#  {'trip_distance': 2.64,
#   'pickup_latitude': 40.750492,
#   'pickup_longitude': 40.750492},
#  {'trip_distance': 11.3,
#   'pickup_latitude': 40.779416,
#   'pickup_longitude': 40.779416},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.779454,
#   'pickup_longitude': 40.779454},
#  {'trip_distance': 8.12,
#   'pickup_latitude': 40.773952,
#   'pickup_longitude': 40.773952},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.756805,
#   'pickup_longitude': 40.756805},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.766251,
#   'pickup_longitude': 40.766251},
#  {'trip_distance': 4.6,
#   'pickup_latitude': 40.747098,
#   'pickup_longitude': 40.747098},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.774347,
#   'pickup_longitude': 40.774347},
#  {'trip_distance': 3.05,
#   'pickup_latitude': 40.73735,
#   'pickup_longitude': 40.73735},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.755507,
#   'pickup_longitude': 40.755507},
#  {'trip_distance': 1.09, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.77734,
#   'pickup_longitude': 40.77734},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.730313,
#   'pickup_longitude': 40.730313},
#  {'trip_distance': 0.78,
#   'pickup_latitude': 40.770965,
#   'pickup_longitude': 40.770965},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.747897,
#   'pickup_longitude': 40.747897},
#  {'trip_distance': 3.5,
#   'pickup_latitude': 40.743013,
#   'pickup_longitude': 40.743013},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.757036,
#   'pickup_longitude': 40.757036},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.75083,
#   'pickup_longitude': 40.75083},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.747865,
#   'pickup_longitude': 40.747865},
#  {'trip_distance': 1.66,
#   'pickup_latitude': 40.758215,
#   'pickup_longitude': 40.758215},
#  {'trip_distance': 2.38,
#   'pickup_latitude': 40.750687,
#   'pickup_longitude': 40.750687},
#  {'trip_distance': 1.82,
#   'pickup_latitude': 40.734432,
#   'pickup_longitude': 40.734432},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.766799,
#   'pickup_longitude': 40.766799},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.752133,
#   'pickup_longitude': 40.752133},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.719627,
#   'pickup_longitude': 40.719627},
#  {'trip_distance': 12.55,
#   'pickup_latitude': 40.77012,
#   'pickup_longitude': 40.77012},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.753714,
#   'pickup_longitude': 40.753714},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.779378,
#   'pickup_longitude': 40.779378},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.764967,
#   'pickup_longitude': 40.764967},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.724772,
#   'pickup_longitude': 40.724772},
#  {'trip_distance': 2.18,
#   'pickup_latitude': 40.734817,
#   'pickup_longitude': 40.734817},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.751752,
#   'pickup_longitude': 40.751752},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.756564,
#   'pickup_longitude': 40.756564},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.742736,
#   'pickup_longitude': 40.742736},
#  {'trip_distance': 9.7, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.741672,
#   'pickup_longitude': 40.741672},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.72597,
#   'pickup_longitude': 40.72597},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.743772,
#   'pickup_longitude': 40.743772},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.71032,
#   'pickup_longitude': 40.71032},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.710885,
#   'pickup_longitude': 40.710885},
#  {'trip_distance': 1.46,
#   'pickup_latitude': 40.768567,
#   'pickup_longitude': 40.768567},
#  {'trip_distance': 4.19,
#   'pickup_latitude': 40.755322,
#   'pickup_longitude': 40.755322},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.750872,
#   'pickup_longitude': 40.750872},
#  {'trip_distance': 5.8,
#   'pickup_latitude': 40.691887,
#   'pickup_longitude': 40.691887},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 40.753002,
#   'pickup_longitude': 40.753002},
#  {'trip_distance': 0.34,
#   'pickup_latitude': 40.765657,
#   'pickup_longitude': 40.765657},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.718429,
#   'pickup_longitude': 40.718429},
#  {'trip_distance': 0.55,
#   'pickup_latitude': 40.75261,
#   'pickup_longitude': 40.75261},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.774841,
#   'pickup_longitude': 40.774841},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.820267,
#   'pickup_longitude': 40.820267},
#  {'trip_distance': 1.98,
#   'pickup_latitude': 40.749905,
#   'pickup_longitude': 40.749905},
#  {'trip_distance': 1.55,
#   'pickup_latitude': 40.790222,
#   'pickup_longitude': 40.790222},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.751243,
#   'pickup_longitude': 40.751243},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.769372,
#   'pickup_longitude': 40.769372},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.802452,
#   'pickup_longitude': 40.802452},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.740012,
#   'pickup_longitude': 40.740012},
#  {'trip_distance': 1.79,
#   'pickup_latitude': 40.724477,
#   'pickup_longitude': 40.724477},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.649679,
#   'pickup_longitude': 40.649679},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.763434,
#   'pickup_longitude': 40.763434},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.813836,
#   'pickup_longitude': 40.813836},
#  {'trip_distance': 4.4,
#   'pickup_latitude': 40.748613,
#   'pickup_longitude': 40.748613},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.756067,
#   'pickup_longitude': 40.756067},
#  {'trip_distance': 0.96,
#   'pickup_latitude': 40.751127,
#   'pickup_longitude': 40.751127},
#  {'trip_distance': 10.9,
#   'pickup_latitude': 40.757541,
#   'pickup_longitude': 40.757541},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.783417,
#   'pickup_longitude': 40.783417},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.755617,
#   'pickup_longitude': 40.755617},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.770837,
#   'pickup_longitude': 40.770837},
#  {'trip_distance': 2.55,
#   'pickup_latitude': 40.770932,
#   'pickup_longitude': 40.770932},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.742625,
#   'pickup_longitude': 40.742625},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.767386,
#   'pickup_longitude': 40.767386},
#  {'trip_distance': 1.62,
#   'pickup_latitude': 40.729417,
#   'pickup_longitude': 40.729417},
#  {'trip_distance': 1.4, 'pickup_latitude': 0.0, 'pickup_longitude': 0.0},
#  {'trip_distance': 3.38,
#   'pickup_latitude': 40.76026,
#   'pickup_longitude': 40.76026},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.748453,
#   'pickup_longitude': 40.748453},
#  {'trip_distance': 6.5,
#   'pickup_latitude': 40.763605,
#   'pickup_longitude': 40.763605},
#  {'trip_distance': 0.81,
#   'pickup_latitude': 40.735872,
#   'pickup_longitude': 40.735872},
#  {'trip_distance': 0.25,
#   'pickup_latitude': 40.761363,
#   'pickup_longitude': 40.761363},
#  {'trip_distance': 2.86,
#   'pickup_latitude': 40.661145,
#   'pickup_longitude': 40.661145},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.748542,
#   'pickup_longitude': 40.748542},
#  {'trip_distance': 3.7,
#   'pickup_latitude': 40.781112,
#   'pickup_longitude': 40.781112},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.762465,
#   'pickup_longitude': 40.762465},
#  {'trip_distance': 2.27,
#   'pickup_latitude': 40.74805,
#   'pickup_longitude': 40.74805},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.780242,
#   'pickup_longitude': 40.780242},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.764726,
#   'pickup_longitude': 40.764726},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.733294,
#   'pickup_longitude': 40.733294},
#  {'trip_distance': 1.08,
#   'pickup_latitude': 40.74976,
#   'pickup_longitude': 40.74976},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.753168,
#   'pickup_longitude': 40.753168},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.764099,
#   'pickup_longitude': 40.764099},
#  {'trip_distance': 6.8,
#   'pickup_latitude': 40.796757,
#   'pickup_longitude': 40.796757},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.765015,
#   'pickup_longitude': 40.765015},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.722397,
#   'pickup_longitude': 40.722397},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.784722,
#   'pickup_longitude': 40.784722},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.734082,
#   'pickup_longitude': 40.734082},
#  {'trip_distance': 0.56,
#   'pickup_latitude': 40.74772,
#   'pickup_longitude': 40.74772},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.774329,
#   'pickup_longitude': 40.774329},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.742366,
#   'pickup_longitude': 40.742366},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.739342,
#   'pickup_longitude': 40.739342},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.756363,
#   'pickup_longitude': 40.756363},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.738254,
#   'pickup_longitude': 40.738254},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.735046,
#   'pickup_longitude': 40.735046},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.755857,
#   'pickup_longitude': 40.755857},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.772357,
#   'pickup_longitude': 40.772357},
#  {'trip_distance': 1.78,
#   'pickup_latitude': 40.775272,
#   'pickup_longitude': 40.775272},
#  {'trip_distance': 7.68,
#   'pickup_latitude': 40.763642,
#   'pickup_longitude': 40.763642},
#  {'trip_distance': 12.15,
#   'pickup_latitude': 40.768787,
#   'pickup_longitude': 40.768787},
#  {'trip_distance': 0.83,
#   'pickup_latitude': 40.772327,
#   'pickup_longitude': 40.772327},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.750617,
#   'pickup_longitude': 40.750617},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.74049,
#   'pickup_longitude': 40.74049},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.759067,
#   'pickup_longitude': 40.759067},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': 40.762444},
#  {'trip_distance': 9.25,
#   'pickup_latitude': 40.774087,
#   'pickup_longitude': 40.774087},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.781736,
#   'pickup_longitude': 40.781736},
#  {'trip_distance': 1.46,
#   'pickup_latitude': 40.757812,
#   'pickup_longitude': 40.757812},
#  {'trip_distance': 0.53,
#   'pickup_latitude': 40.787172,
#   'pickup_longitude': 40.787172}]

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's get a sense of our trip data.  We can use the `folium` Python library to plot a map of Manhattan, and our data.  First we must import `folium`, and then use the `Map` function to pass through a `location`, and `zoom_start`.  If a map isn't showing up below, copy and paste the command `pip install -r requirements.txt` into your terminal to install `folium` then try again.

# %%
import folium
manhattan_map = folium.Map(location=[40.7589, -73.9851], zoom_start=11)

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, now let's see how we could add a dot to mark a specific location.  We'll start with Times Square.

# %%
marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
marker.add_to(manhattan_map)

# %% [markdown]
# Above, we first create a marker.  Then we add that circle marker to the `manhattan_map` we created earlier.

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Do you see that blue dot near Time's Square?  That is our marker.
#
# So now that we can plot one marker on a map, we should have a sense of how we can plot many markers on a map to display our taxi ride data.  We simply plot a map, and then we add a marker for each location of a taxi trip.
#
# Now let's write some functions to allow us to plot maps and add markers a little more easily.

# %% [markdown]
# #### Writing some map plotting functions

# %% [markdown]
# As a first step towards this, note that the functions to create both a marker and map each take in a location as two element list, representing the latitude and longitude values.  Take another look:
#
# ```python
# marker = folium.CircleMarker(location = [40.7589, -73.9851])
# manhattan_map = folium.Map(location=[40.7589, -73.9851])
# ```
#
# So let's write a function called to create this two element list from a trip.  Write a function called `location` that  takes in a trip as an argument and returns a list where the first element is the latitude and the second is the longitude.  Remember that a location looks like the following:

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115,  'trip_distance': 18.38}
first_trip
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %%
def location(trip):
    return [trip['pickup_latitude'], trip['pickup_longitude']]

# %%
first_location = location(first_trip) # [40.64499, -73.78115]
first_location # [40.64499, -73.78115]
# Out:
# [40.64499, -73.78115]

# %% [markdown]
# Ok, now that we can turn a trip into a location, let's turn a location into a marker.  Write a function called `to_marker` that takes in a location (in the form of a list) as an argument, and returns a folium `circleMarker` for that location.  The radius of the marker should always equal 6.

# %%
def to_marker(location):
    return folium.CircleMarker(location, radius = 6)

# %%
import json
times_square_marker = to_marker([40.7589, -73.9851])

times_square_marker and times_square_marker.location # [40.7589, -73.9851]
# times_square_marker and json.loads(times_square_marker.options)['radius'] # 6
# Out:
# [40.7589, -73.9851]

# %% [markdown]
# Ok, now that we know how to produce a single marker, let's write a function to produce lots.  We can write a function called `markers_from_trips` that takes in a list of trips, and returns a marker object for each trip.

# %%
def markers_from_trips(trips):
    locations = list(map(lambda trip: location(trip), trips))
    return list(map(lambda location: to_marker(location),locations))

# %%
trip_markers = markers_from_trips(cleaned_trips)

# %%
cleaned_trips[0:4]
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': 40.64499},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': 40.766931},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': 40.77773},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': 40.795678}]

# %%
trip_markers and len(trip_markers) # 1000

list(map(lambda marker: marker.location, trip_markers[0:4]))
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]
# Out:
# [[40.64499, 40.64499],
#  [40.766931, 40.766931],
#  [40.77773, 40.77773],
#  [40.795678, 40.795678]]

# %% [markdown]
# Ok, now that we have a function that creates locations, and a function that creates markers, it is time to write a function to plot a map.
#
# Write a function called `map_from` that, provided the first argument of a list location and second argument an integer representing the `zoom_start`, returns a `folium` map the corresponding location and `zoom_start` attributes.
#
# > Hint: The following is how to write a map with folium:
# > ```python
#     folium.Map(location=location, zoom_start=zoom_amount)
# > ```

# %%
def map_from(location, zoom_amount):
    return folium.Map(location=location, zoom_start=zoom_amount)

# %%
times_square_map = map_from([40.7589, -73.9851], 15)
times_square_map and times_square_map.location # [40.7589, -73.9851]
# Out:
# [40.7589, -73.9851]

# %%
times_square_marker and times_square_marker.add_to(times_square_map)
times_square_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have a marker and a map, now let's write a function that adds a lot of markers to a map.  This function should add each marker in the list to the map object then return the updated map object.

# %%
manhattan_map = map_from([40.7589, -73.9851], 13)

# %%
def add_markers(markers, map_obj):
    for marker in markers:
        marker.add_to(map_obj)
    return map_obj

# %%
map_with_markers = add_markers(trip_markers, manhattan_map)

# %%
map_with_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
# Here we once again apply the nearest neighbors formula. As a first step, write a function named `distance_location` that calculates the distance in pickup location between two trips.

# %%
import math

def distance_location(selected_trip, neighbor_trip):
    pass

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
distance_first_and_second = distance_location(first_trip, second_trip)

distance_first_and_second and round(distance_first_and_second, 3) # 0.235
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-42-f86a136eedd4> in <module>
#       1 first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
#       2 second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
# ----> 3 distance_first_and_second = distance_location(first_trip, second_trip)
#       4
#       5 distance_first_and_second and round(distance_first_and_second, 3) # 0.235
#
# NameError: name 'distance_location' is not defined

# %% [markdown]
# Ok, next write a function called `distance_between_neighbors` that adds a new key-value pair, called `distance_from_selected`, that calculates the distance of the `neighbor_trip` from the `selected_trip`.

# %%
def distance_between_neighbors(selected_trip, neighbor_trip):
    pass

# %%
distance_between_neighbors(first_trip, second_trip)

# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}

# %% [markdown]
# Ok, now our `neighbor_trip` has another attribute called `distance_from_selected`, that indicates the distance from the `neighbor_trip`'s pickup location from the `selected_trip`.

# %% [markdown]
# > ** Understand the data:** Our dictionary now has a few attributes, two of which say distance.  Let's make sure we understand the difference.
# > * **`distance_from_selected`:** This is our calculation of the distance of the neighbor's pickup location from the selected trip.
# > * **`trip_distance`:** This is the attribute we were provided initially.  It tells us the length of the neighbor's taxi trip from pickup to drop-off.

# %% [markdown]
# Next, write a function called `distance_all` that provided a list of neighbors, returns each of those neighbors with their respective `distance_from_selected` numbers.

# %%
def distance_all(selected_individual, neighbors):
    pass

# %%
cleaned_trips and distance_all(first_trip, cleaned_trips[0:4])

# %% [markdown]
# Now write the nearest neighbors formula to calculate the distance of the `selected_trip` from all of the `cleaned_trips` in our dataset.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_trip, trips, number = 3):
    pass

# %%
new_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
nearest_three_neighbors
# [{'distance_from_selected': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_selected': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_selected': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]

# %% [markdown]
# Ok great! Now that we can provide a new trip location, and find the distances of the three nearest trips, we can take  calculate an estimate of the trip distance for that new trip location.
#
# We do so simply by calculating the average of it's nearest neighbors.

# %%
import statistics
def mean_distance(neighbors):
    nearest_distances = list(map(lambda neighbor: neighbor['trip_distance'], neighbors))
    return round(statistics.mean(nearest_distances), 3)

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
distance_estimate_of_selected_trip = mean_distance(nearest_three_neighbors) # 12.593
distance_estimate_of_selected_trip

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now, as we know from the last lesson, one tricky element is to determine how many neighbors to choose, our $k$ value,  before calculating the average.  We want to choose our value of $k$ such that it properly matches actual data, and so that it applies to new data.  There are fancy formulas to ensure that we **train** our algorithm so that our formula is optimized for all data, but here let's see different $k$ values manually.  This is the gist of choosing our $k$ value:
#
# * If we choose a $k$ value too low, our formula will be too heavily influenced by a single neighbor, whereas if our $k$ value is too high, we will be choosing so many neighbors that our nearest neighbors formula will not be adjust enough according to locations.
#
# Ok, let's experiment with this.

# %% [markdown]
# First, let's choose a midtown location, to see what the trip distance would be.  A Google search reveals the coordinates of 51st and 7th avenue to be the following.

# %%
midtown_trip = dict(pickup_latitude=40.761710, pickup_longitude=-73.982760)

# %%
seven_closest = nearest_neighbors(midtown_trip, cleaned_trips, number = 7)
seven_closest
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance_from_selected': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance_from_selected': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'distance_from_selected': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance_from_selected': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance_from_selected': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'distance_from_selected': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance_from_selected': 0.0020684557041472677}]

# %% [markdown]
# Looking at the `distance_from_selected` it appears that our our trips are still fairly close to our selected trip.  Notice that most of the data is within a distance of .002 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.
#
# Still, it's hard to know what distance in latitude and longitude really look like, so let's map the data.

# %%
midtown_location = location(midtown_trip) # [40.76171, -73.98276]
midtown_map = map_from(midtown_location, 16)
closest_markers = markers_from_trips(seven_closest)

add_markers(closest_markers, midtown_map)

# %% [markdown]
# Ok.  These locations stay fairly close to our estimated location of 51st street and 7th Avenue.  So they could be a good estimate of a trip distance.

# %%
mean_distance(seven_closest) # 2.009

# %% [markdown]
# Ok, now let's try a different location

# %%
charging_bull_closest = nearest_neighbors({'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}, cleaned_trips, number = 12)

# %%
mean_distance(charging_bull_closest) # 3.145

# %% [markdown]
# Ok, so there appears to be a significant difference between choosing a location near Times Square versus choosing a location at Wall Street.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used the nearest neighbors function to predict the length of a taxi ride.  To do so, we selected a location, then found a number of taxi rides closest to that location, and finally took the average trip lengths of the nearest taxi rides to find an estimate of the new ride's trip length.  You can see that even with just a little bit of math and programming we can begin to make meaningful predictions with data.
